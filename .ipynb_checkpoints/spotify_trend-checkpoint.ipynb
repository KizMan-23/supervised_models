# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
spotify = pd.read_csv("C:/Users/Hp Pc/Downloads/Most Streamed Spotify Songs 2024.csv", encoding = "unicode_escape")

# %%
spotify
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# 0      Tommy Richman    4/26/2024  QM24S2402528             1        725.4
# 1     Kendrick Lamar     5/4/2024  USUG12400910             2        545.9
# 2            Artemas    3/19/2024  QZJ842400387             3        538.4
# 3        Miley Cyrus    1/12/2023  USSM12209777             4        444.9
# 4             Eminem    5/31/2024  USUG12403398             5        423.3
# ...              ...          ...           ...           ...          ...
# 4595     $uicideboy$     9/5/2017  QM8DG1703420         4,585         19.4
# 4596      Atif Aslam    7/27/2018  INT101800122         4,575         19.4
# 4597        Lil Baby    2/28/2020  USUG12000043         4,571         19.4
# 4598    Arijit Singh    11/8/2016  INY091600067         4,591         19.4
# 4599       Arcï¿½ï¿½    4/11/2017  USB271700107         4,593         19.4
#
#      Spotify Streams Spotify Playlist Count Spotify Playlist Reach  ...  \
# 0        390,470,936                 30,716            196,631,588  ...
# 1        323,703,884                 28,113            174,597,137  ...
# 2        601,309,283                 54,331            211,607,669  ...
# 3      2,031,280,633                269,802            136,569,078  ...
# 4        107,034,922                  7,223            151,469,874  ...
# ...              ...                    ...                    ...  ...
# 4595     305,049,963                 65,770              5,103,054  ...
# 4596      52,282,360                  4,602              1,449,767  ...
# 4597     189,972,685                 72,066              6,704,802  ...
# 4598     145,467,020                 14,037              7,387,064  ...
# 4599     255,740,653                 32,138             14,066,526  ...
#
#       SiriusXM Spins Deezer Playlist Count Deezer Playlist Reach  \
# 0                684                  62.0            17,598,718
# 1                  3                  67.0            10,422,430
# 2                536                 136.0            36,321,847
# 3              2,182                 264.0            24,684,248
# 4                  1                  82.0            17,660,624
# ...              ...                   ...                   ...
# 4595             NaN                   2.0                14,217
# 4596             NaN                   1.0                   927
# 4597             NaN                   1.0                    74
# 4598             NaN                   NaN                   NaN
# 4599             NaN                   4.0               127,479
#
#      Amazon Playlist Count Pandora Streams Pandora Track Stations  \
# 0                    114.0      18,004,655                 22,931
# 1                    111.0       7,780,028                 28,444
# 2                    172.0       5,022,621                  5,639
# 3                    210.0     190,260,277                203,384
# 4                    105.0       4,493,884                  7,006
# ...                    ...             ...                    ...
# 4595                   NaN      20,104,066                 13,184
# 4596                   NaN             NaN                    NaN
# 4597                   6.0      84,426,740                 28,999
# 4598                   7.0       6,817,840                    NaN
# 4599                   4.0      69,006,739                 11,320
#
#      Soundcloud Streams  Shazam Counts TIDAL Popularity Explicit Track
# 0             4,818,457      2,669,262              NaN              0
# 1             6,623,075      1,118,279              NaN              1
# 2             7,208,651      5,285,340              NaN              0
# 3                   NaN     11,822,942              NaN              0
# 4               207,179        457,017              NaN              1
# ...                 ...            ...              ...            ...
# 4595         50,633,006        656,337              NaN              1
# 4596                NaN        193,590              NaN              0
# 4597                NaN      1,135,998              NaN              1
# 4598                NaN        448,292              NaN              0
# 4599                NaN        767,006              NaN              1
#
# [4600 rows x 29 columns]

# %%
spotify.columns.to_list()
# Out:
# ['Track',
#  'Album Name',
#  'Artist',
#  'Release Date',
#  'ISRC',
#  'All Time Rank',
#  'Track Score',
#  'Spotify Streams',
#  'Spotify Playlist Count',
#  'Spotify Playlist Reach',
#  'Spotify Popularity',
#  'YouTube Views',
#  'YouTube Likes',
#  'TikTok Posts',
#  'TikTok Likes',
#  'TikTok Views',
#  'YouTube Playlist Reach',
#  'Apple Music Playlist Count',
#  'AirPlay Spins',
#  'SiriusXM Spins',
#  'Deezer Playlist Count',
#  'Deezer Playlist Reach',
#  'Amazon Playlist Count',
#  'Pandora Streams',
#  'Pandora Track Stations',
#  'Soundcloud Streams',
#  'Shazam Counts',
#  'TIDAL Popularity',
#  'Explicit Track']

# %% [raw]
# PREPROCESSING

# %%
len(spotify.Track.value_counts())
# Out:
# 4370

# %%
len(spotify['Album Name'].value_counts())
# Out:
# 4005

# %%
len(spotify.Artist.value_counts())
# Out:
# 1999

# %%
popularity = spotify.filter(regex = 'Stream|Views')

# %%
popularity.columns
# Out:
# Index(['Spotify Streams', 'YouTube Views', 'TikTok Views', 'Pandora Streams',
#        'Soundcloud Streams'],
#       dtype='object')

# %%
popularity.isna().sum()
# Out:
# Spotify Streams        113
# YouTube Views          308
# TikTok Views           981
# Pandora Streams       1106
# Soundcloud Streams    3333
# dtype: int64

# %%
popularity = popularity.fillna(0)

# %%
popularity.isna().sum()
# Out:
# Spotify Streams       0
# YouTube Views         0
# TikTok Views          0
# Pandora Streams       0
# Soundcloud Streams    0
# dtype: int64

# %%
#popularity = popularity.replace(",", " ")
popularity = popularity.replace( regex= ",", value= "")

# %%
popularity
# Out:
#      Spotify Streams YouTube Views TikTok Views Pandora Streams  \
# 0          390470936      84274754   5332281936        18004655
# 1          323703884     116347040    208339025         7780028
# 2          601309283     122599116   3369120610         5022621
# 3         2031280633    1096100899  14603725994       190260277
# 4          107034922      77373957            0         4493884
# ...              ...           ...          ...             ...
# 4595       305049963     149247747    143934379        20104066
# 4596        52282360     943920245        19935               0
# 4597       189972685     201027333     36849005        84426740
# 4598       145467020    1118595159     37757301         6817840
# 4599       255740653     866300755     70196388        69006739
#
#      Soundcloud Streams
# 0               4818457
# 1               6623075
# 2               7208651
# 3                     0
# 4                207179
# ...                 ...
# 4595           50633006
# 4596                  0
# 4597                  0
# 4598                  0
# 4599                  0
#
# [4600 rows x 5 columns]

# %%
popularity = popularity.apply(lambda x: pd.to_numeric(x, errors = 'coerce'))

# %%
popularity = popularity.replace([float('inf'), -float('inf')], 0)

# %%
popularity.dtypes
# Out:
# Spotify Streams       int64
# YouTube Views         int64
# TikTok Views          int64
# Pandora Streams       int64
# Soundcloud Streams    int64
# dtype: object

# %%
popularity
# Out:
#       Spotify Streams  YouTube Views  TikTok Views  Pandora Streams  \
# 0           390470936       84274754    5332281936         18004655
# 1           323703884      116347040     208339025          7780028
# 2           601309283      122599116    3369120610          5022621
# 3          2031280633     1096100899   14603725994        190260277
# 4           107034922       77373957             0          4493884
# ...               ...            ...           ...              ...
# 4595        305049963      149247747     143934379         20104066
# 4596         52282360      943920245         19935                0
# 4597        189972685      201027333      36849005         84426740
# 4598        145467020     1118595159      37757301          6817840
# 4599        255740653      866300755      70196388         69006739
#
#       Soundcloud Streams
# 0                4818457
# 1                6623075
# 2                7208651
# 3                      0
# 4                 207179
# ...                  ...
# 4595            50633006
# 4596                   0
# 4597                   0
# 4598                   0
# 4599                   0
#
# [4600 rows x 5 columns]

# %%
social_reach  = spotify.filter(regex = 'Reach')
social_reach['Amazon Reach'] = spotify['Amazon Playlist Count']
social_reach['Apple Reach'] = spotify['Apple Music Playlist Count']

# %%
social_reach
# Out:
#      Spotify Playlist Reach YouTube Playlist Reach Deezer Playlist Reach  \
# 0               196,631,588            150,597,040            17,598,718
# 1               174,597,137            156,380,351            10,422,430
# 2               211,607,669            373,784,955            36,321,847
# 3               136,569,078          3,351,188,582            24,684,248
# 4               151,469,874            112,763,851            17,660,624
# ...                     ...                    ...                   ...
# 4595              5,103,054                 53,016                14,217
# 4596              1,449,767             24,973,048                   927
# 4597              6,704,802             29,253,152                    74
# 4598              7,387,064             25,150,516                   NaN
# 4599             14,066,526            175,831,376               127,479
#
#       Amazon Reach  Apple Reach
# 0            114.0        210.0
# 1            111.0        188.0
# 2            172.0        190.0
# 3            210.0        394.0
# 4            105.0        182.0
# ...            ...          ...
# 4595           NaN          3.0
# 4596           NaN          1.0
# 4597           6.0         19.0
# 4598           7.0          1.0
# 4599           4.0         11.0
#
# [4600 rows x 5 columns]

# %%
social_reach = social_reach.fillna(0)

# %%
social_reach.isnull().sum()
# Out:
# Spotify Playlist Reach    0
# YouTube Playlist Reach    0
# Deezer Playlist Reach     0
# Amazon Reach              0
# Apple Reach               0
# dtype: int64

# %%
social_reach = social_reach.apply(lambda x: x.replace(regex= ",", value= "")) #remove all the commas
social_reach = social_reach.apply(lambda x: pd.to_numeric(x, errors = 'coerce'))
#social_reach = social_reach.replace([float('inf'), -float('inf')], 0)

# %%
social_reach
# Out:
#       Spotify Playlist Reach  YouTube Playlist Reach  Deezer Playlist Reach  \
# 0                  196631588               150597040               17598718
# 1                  174597137               156380351               10422430
# 2                  211607669               373784955               36321847
# 3                  136569078              3351188582               24684248
# 4                  151469874               112763851               17660624
# ...                      ...                     ...                    ...
# 4595                 5103054                   53016                  14217
# 4596                 1449767                24973048                    927
# 4597                 6704802                29253152                     74
# 4598                 7387064                25150516                      0
# 4599                14066526               175831376                 127479
#
#       Amazon Reach  Apple Reach
# 0            114.0        210.0
# 1            111.0        188.0
# 2            172.0        190.0
# 3            210.0        394.0
# 4            105.0        182.0
# ...            ...          ...
# 4595           0.0          3.0
# 4596           0.0          1.0
# 4597           6.0         19.0
# 4598           7.0          1.0
# 4599           4.0         11.0
#
# [4600 rows x 5 columns]

# %%
popularity.columns
# Out:
# Index(['Spotify Streams', 'YouTube Views', 'TikTok Views', 'Pandora Streams',
#        'Soundcloud Streams'],
#       dtype='object')

# %%
popularity['pop_score'] = (popularity['Spotify Streams'] + 
                           popularity['YouTube Views'] + 
                           popularity['TikTok Views'] +
                           popularity['Pandora Streams'] + 
                           popularity['Soundcloud Streams'])

# %%
popularity['pop_score'] = np.log(popularity['pop_score'])
# Out:
# C:\Users\Hp Pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
len(popularity[popularity['pop_score'] <= 0])
# Out:
# 22

# %%
popularity = popularity[popularity['pop_score'] > 0]

# %%
popularity['pop_score'] = popularity['pop_score'].apply(lambda x: round(x,2))
# Out:
# C:\Users\Hp Pc\AppData\Local\Temp\ipykernel_6492\433075983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popularity['pop_score'] = popularity['pop_score'].apply(lambda x: round(x,2))

# %%
popularity
# Out:
#       Spotify Streams  YouTube Views  TikTok Views  Pandora Streams  \
# 0           390470936       84274754    5332281936         18004655
# 1           323703884      116347040     208339025          7780028
# 2           601309283      122599116    3369120610          5022621
# 3          2031280633     1096100899   14603725994        190260277
# 4           107034922       77373957             0          4493884
# ...               ...            ...           ...              ...
# 4595        305049963      149247747     143934379         20104066
# 4596         52282360      943920245         19935                0
# 4597        189972685      201027333      36849005         84426740
# 4598        145467020     1118595159      37757301          6817840
# 4599        255740653      866300755      70196388         69006739
#
#       Soundcloud Streams  pop_score
# 0                4818457      22.49
# 1                6623075      20.31
# 2                7208651      22.14
# 3                      0      23.61
# 4                 207179      19.06
# ...                  ...        ...
# 4595            50633006      20.32
# 4596                   0      20.72
# 4597                   0      20.05
# 4598                   0      20.99
# 4599                   0      20.96
#
# [4578 rows x 6 columns]

# %%
social_reach.columns
# Out:
# Index(['Spotify Playlist Reach', 'YouTube Playlist Reach',
#        'Deezer Playlist Reach', 'Amazon Reach', 'Apple Reach'],
#       dtype='object')

# %%
social_reach['reach'] = (social_reach['Spotify Playlist Reach'] +
                        social_reach['YouTube Playlist Reach'] +
                        social_reach['Deezer Playlist Reach'] +
                        social_reach['Amazon Reach'] +
                        social_reach['Apple Reach'])

# %%
social_reach['reach'] = np.log(social_reach['reach'])
# Out:
# C:\Users\Hp Pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
len(social_reach[social_reach['reach'] <= 0])
# Out:
# 60

# %%
social_reach = social_reach[social_reach['reach'] >0]

# %%
social_reach['reach'] = social_reach['reach'].apply(lambda x: round(x,2))
# Out:
# C:\Users\Hp Pc\AppData\Local\Temp\ipykernel_6492\907847438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   social_reach['reach'] = social_reach['reach'].apply(lambda x: round(x,2))

# %%
social_reach
# Out:
#       Spotify Playlist Reach  YouTube Playlist Reach  Deezer Playlist Reach  \
# 0                  196631588               150597040               17598718
# 1                  174597137               156380351               10422430
# 2                  211607669               373784955               36321847
# 3                  136569078              3351188582               24684248
# 4                  151469874               112763851               17660624
# ...                      ...                     ...                    ...
# 4595                 5103054                   53016                  14217
# 4596                 1449767                24973048                    927
# 4597                 6704802                29253152                     74
# 4598                 7387064                25150516                      0
# 4599                14066526               175831376                 127479
#
#       Amazon Reach  Apple Reach  reach
# 0            114.0        210.0  19.71
# 1            111.0        188.0  19.65
# 2            172.0        190.0  20.25
# 3            210.0        394.0  21.98
# 4            105.0        182.0  19.46
# ...            ...          ...    ...
# 4595           0.0          3.0  15.46
# 4596           0.0          1.0  17.09
# 4597           6.0         19.0  17.40
# 4598           7.0          1.0  17.30
# 4599           4.0         11.0  19.06
#
# [4540 rows x 6 columns]

# %%
track_stats = popularity.merge(social_reach,left_index=True, right_index=True)

# %%
track_stats
# Out:
#       Spotify Streams  YouTube Views  TikTok Views  Pandora Streams  \
# 0           390470936       84274754    5332281936         18004655
# 1           323703884      116347040     208339025          7780028
# 2           601309283      122599116    3369120610          5022621
# 3          2031280633     1096100899   14603725994        190260277
# 4           107034922       77373957             0          4493884
# ...               ...            ...           ...              ...
# 4595        305049963      149247747     143934379         20104066
# 4596         52282360      943920245         19935                0
# 4597        189972685      201027333      36849005         84426740
# 4598        145467020     1118595159      37757301          6817840
# 4599        255740653      866300755      70196388         69006739
#
#       Soundcloud Streams  pop_score  Spotify Playlist Reach  \
# 0                4818457      22.49               196631588
# 1                6623075      20.31               174597137
# 2                7208651      22.14               211607669
# 3                      0      23.61               136569078
# 4                 207179      19.06               151469874
# ...                  ...        ...                     ...
# 4595            50633006      20.32                 5103054
# 4596                   0      20.72                 1449767
# 4597                   0      20.05                 6704802
# 4598                   0      20.99                 7387064
# 4599                   0      20.96                14066526
#
#       YouTube Playlist Reach  Deezer Playlist Reach  Amazon Reach  \
# 0                  150597040               17598718         114.0
# 1                  156380351               10422430         111.0
# 2                  373784955               36321847         172.0
# 3                 3351188582               24684248         210.0
# 4                  112763851               17660624         105.0
# ...                      ...                    ...           ...
# 4595                   53016                  14217           0.0
# 4596                24973048                    927           0.0
# 4597                29253152                     74           6.0
# 4598                25150516                      0           7.0
# 4599               175831376                 127479           4.0
#
#       Apple Reach  reach
# 0           210.0  19.71
# 1           188.0  19.65
# 2           190.0  20.25
# 3           394.0  21.98
# 4           182.0  19.46
# ...           ...    ...
# 4595          3.0  15.46
# 4596          1.0  17.09
# 4597         19.0  17.40
# 4598          1.0  17.30
# 4599         11.0  19.06
#
# [4534 rows x 12 columns]

# %%
spotify.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity',
#        'Explicit Track'],
#       dtype='object')

# %%
track_stats = track_stats.merge(spotify[['Track', 'Album Name', 'Artist', 'Release Date', 'Track Score', 'Explicit Track']], 
                                left_index=True, right_index=True)

# %%
track_stats
# Out:
#       Spotify Streams  YouTube Views  TikTok Views  Pandora Streams  \
# 0           390470936       84274754    5332281936         18004655
# 1           323703884      116347040     208339025          7780028
# 2           601309283      122599116    3369120610          5022621
# 3          2031280633     1096100899   14603725994        190260277
# 4           107034922       77373957             0          4493884
# ...               ...            ...           ...              ...
# 4595        305049963      149247747     143934379         20104066
# 4596         52282360      943920245         19935                0
# 4597        189972685      201027333      36849005         84426740
# 4598        145467020     1118595159      37757301          6817840
# 4599        255740653      866300755      70196388         69006739
#
#       Soundcloud Streams  pop_score  Spotify Playlist Reach  \
# 0                4818457      22.49               196631588
# 1                6623075      20.31               174597137
# 2                7208651      22.14               211607669
# 3                      0      23.61               136569078
# 4                 207179      19.06               151469874
# ...                  ...        ...                     ...
# 4595            50633006      20.32                 5103054
# 4596                   0      20.72                 1449767
# 4597                   0      20.05                 6704802
# 4598                   0      20.99                 7387064
# 4599                   0      20.96                14066526
#
#       YouTube Playlist Reach  Deezer Playlist Reach  Amazon Reach  \
# 0                  150597040               17598718         114.0
# 1                  156380351               10422430         111.0
# 2                  373784955               36321847         172.0
# 3                 3351188582               24684248         210.0
# 4                  112763851               17660624         105.0
# ...                      ...                    ...           ...
# 4595                   53016                  14217           0.0
# 4596                24973048                    927           0.0
# 4597                29253152                     74           6.0
# 4598                25150516                      0           7.0
# 4599               175831376                 127479           4.0
#
#       Apple Reach  reach                            Track  \
# 0           210.0  19.71              MILLION DOLLAR BABY
# 1           188.0  19.65                      Not Like Us
# 2           190.0  20.25       i like the way you kiss me
# 3           394.0  21.98                          Flowers
# 4           182.0  19.46                          Houdini
# ...           ...    ...                              ...
# 4595          3.0  15.46                For the Last Time
# 4596          1.0  17.09                 Dil Meri Na Sune
# 4597         19.0  17.40            Grace (feat. 42 Dugg)
# 4598          1.0  17.30              Nashe Si Chadh Gayi
# 4599         11.0  19.06  Me Acostumbre (feat. Bad Bunny)
#
#                             Album Name          Artist Release Date  \
# 0         Million Dollar Baby - Single   Tommy Richman    4/26/2024
# 1                          Not Like Us  Kendrick Lamar     5/4/2024
# 2           I like the way you kiss me         Artemas    3/19/2024
# 3                     Flowers - Single     Miley Cyrus    1/12/2023
# 4                              Houdini          Eminem    5/31/2024
# ...                                ...             ...          ...
# 4595                 For the Last Time     $uicideboy$     9/5/2017
# 4596  Dil Meri Na Sune (From "Genius")      Atif Aslam    7/27/2018
# 4597                           My Turn        Lil Baby    2/28/2020
# 4598             November Top 10 Songs    Arijit Singh    11/8/2016
# 4599   Me Acostumbre (feat. Bad Bunny)       Arcï¿½ï¿½    4/11/2017
#
#       Track Score  Explicit Track
# 0           725.4               0
# 1           545.9               1
# 2           538.4               0
# 3           444.9               0
# 4           423.3               1
# ...           ...             ...
# 4595         19.4               1
# 4596         19.4               0
# 4597         19.4               1
# 4598         19.4               0
# 4599         19.4               1
#
# [4534 rows x 18 columns]

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
track_stats['Release Date'] = pd.to_datetime(track_stats['Release Date'])

track_stats['year'] = track_stats['Release Date'].dt.year

# %%
top_artists = track_stats['Artist'].value_counts().head(15)

top_artists.plot(kind ='bar')
plt.title('Top Artists')
# Out:
# Text(0.5, 1.0, 'Top Artists')

# %%
hg = track_stats.groupby('year')['Release Date'].count().tail(20)

hg.plot(kind='bar')

#songs released each year
# Out:
# <Axes: xlabel='year'>
